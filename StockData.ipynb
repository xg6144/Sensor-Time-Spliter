# %%
import pandas as pd

# %%
news_df = pd.read_csv('news.csv')

# %%
news_df.head()
# Out:
#          뉴스 식별자        일자    언론사                          기고자  \
# 0  1.100101e+06  20210722   경향신문  이윤주 기자 runyj@kyunghyang.com
# 1  2.100101e+06  20210722   매일경제                          김인오
# 2  2.100101e+06  20210722   매일경제                          김혜순
# 3  1.100801e+06  20210722   조선일보                       홍준기 기자
# 4  2.100201e+06  20210722  머니투데이                       최석환|기자
#
#                                   제목     통합 분류1      통합 분류2      통합 분류3  \
# 0  국내 가구당 순자산 평균 5억1220만원 주택이 43% 차지  경제>금융_재테크    경제>증권_증시       경제>유통
# 1     "美증시 변동성 크다" 서학개미 불안불안 피난처는 이곳   경제>증권_증시       경제>자원       경제>외환
# 2    예금 만기로 목돈 쥔 40대 직장인 연금부자 되고 싶다면   경제>증권_증시   경제>금융_재테크     경제>국제경제
# 3       기관 청약에 2585兆 몰렸다 카뱅, 시작부터 대박     경제>부동산    경제>증권_증시   경제>금융_재테크
# 4  현대차 효과?..한국GM 노사도 임금협상 잠정타결-투표 남아   사회>노동_복지         NaN         NaN
#
#   사건/사고 분류1 사건/사고 분류2 사건/사고 분류3          인물  \
# 0       NaN       NaN       NaN         손진식
# 1       NaN       NaN       NaN  조정은,버핏,애크먼
# 2       NaN       NaN       NaN      A씨,송은영
# 3       NaN       NaN       NaN         NaN
# 4       NaN       NaN       NaN         NaN
#
#                                   위치  \
# 0                       프랑스,미국,환산,일본
# 1  레이먼드제임스증권,미국,경기,뉴욕,미,몬델레즈인터내셔널,요동
# 2                      미국,경기,미,한국,선진
# 3                                브라질
# 4                              인천,부평
#
#                                                   기관  \
# 0            통계청,국민순자산,한국은행,국민대차,한국,국민대차대조표,한은,경제통계국
# 1  퍼싱스퀘어캐피털,중국,JP모건,모건스탠리,월가,IBM,엑손모빌,뱅크오브아메리카,리얼...
# 2                         매일경제,중앙은행,타깃,신한PWM잠실센터,S&P
# 3  SK바이오사이언스,SK아이이테크놀로지,신한금융지주,하나금융지주,한국투자증권,공모주,...
# 4                      한국GM,한국 GM,노동조합,현대자동차,현대차,임단협
#
#                                                  키워드  \
# 0  5억,가구,자산,평균,주택,43%,차지,부동산,주식,가격,급등,11%,가계,자산,1...
# 1  증시,변동성,서학개미,불안,불안,피난처,여름휴가철,7~8월,뉴욕,증시,변동성,델타,...
# 2  예금,만기,목돈,직장인,연금부자,정기,예금,만기,A씨,직장인,직접투자,경험,정기예금...
# 3  기관,청약,카뱅,시작,대박,SKIET,청약,기록,공모,3만,확정,일반,공모주,청약,...
# 4  현대차,효과,한국GM,노사,임금,협상,잠정,타결,투표,남아,현대자동차,한국,GM,노...
#
#                                    특성추출(가중치순 상위 50개)  \
# 0  부동산,토지자산,gdp,금융자산,자산가격,5억,비영리단체,대조표,프랑스,순취득액,1...
# 1  미국,코로나19,뉴욕,회복세,셰일,변동성,배당금,변동장세,중국발,데본에너지,월가,배...
# 2       투자자,tdf,운용사,변동성,직장인,한국,미국,각국,송은영,대형주,a씨,정기예금
# 3  공모주,카카오뱅크,증권사,투자자,3만,공모가,시총,핀테크,금융투자,시가총액,경쟁률,...
# 4  격려금,기본급,한국,임단협,조합원,한국gm,잠정합의안,성과급,부평공장,230만,인천...
#
#                                                   본문  \
# 0  ㆍ지난해 부동산 주식 가격 급등으로 가계 자산 11% 가까이 늘어 \nㆍ‘국부’인 ...
# 1  '여름휴가철'을 낀 7~8월은 통상 뉴욕 증시도 변동성이 적은 시기로 통한다. 다만...
# 2  정기예금 만기가 다가오는 40대 직장인 A씨는 직접투자는 경험이 없어 두렵고, 다시...
# 3  올 하반기 공모주 ‘최대어’ 중 하나로 꼽히는 카카오뱅크에 막대한 기관 투자자들의 ...
# 4  [머니투데이 최석환 기자] 현대자동차에 이어 한국GM 노사도 임금협상안에 잠정 합의...
#
#                                                  URL 분석제외 여부
# 0  http://biz.khan.co.kr/khan_art_view.html?artid...     NaN
# 1  http://news.mk.co.kr/newsRead.php?no=708023&ye...     NaN
# 2  http://news.mk.co.kr/newsRead.php?no=708019&ye...     NaN
# 3  https://www.chosun.com/economy/stock-finance/2...     NaN
# 4  http://news.moneytoday.co.kr/view/mtview.php?n...     NaN

# %%
news_df.sort_values(by=['언론사'], axis=0, inplace=True)
group_news = news_df.groupby('언론사')

# %%
group_news = group_news.count()
group_news.to_csv('news_to_num.csv', index=True, mode = 'w', encoding='utf-8')

# %%
group_news
# Out:
#         뉴스 식별자    일자   기고자    제목  통합 분류1  통합 분류2  통합 분류3  사건/사고 분류1  \
# 언론사
# KBS        201   201   195   201     201     175     138         48
# MBC        124   124   100   124     124     114      86         24
# OBS         28    28    28    28      28      26      22          4
# SBS         63    63    59    63      63      54      41         12
# YTN        459   459   459   459     459     396     302        108
# 강원도민일보      14    14    14    14      14       7       3          2
# 강원일보        33    33    18    33      33      24      23          5
# 경기일보        22    22    22    22      22      18      16          2
# 경남도민일보      24    24    24    24      24      20      18          4
# 경남신문        14    14    14    14      14      10       9          0
# 경상일보        29    29    29    29      29      25      20          3
# 경인일보        58    58    58    58      58      40      26          9
# 경향신문       233   233   218   233     233     200     162         44
# 광주매일신문      34    34    31    34      34      30      29          1
# 광주일보        18    18    13    18      18      15      10          4
# 국민일보      2273  2273  2256  2273    2273    2231    2190         56
# 국제신문        62    62    48    62      62      55      48          9
# 내일신문       189   189   185   189     189     172     147         32
# 대구일보        22    22    22    22      22      19      16          4
# 대전일보        36    36    24    36      36      32      30          4
# 동아일보       313   313   287   313     313     283     232         48
# 디지털타임스     606   606   602   606     606     565     487         56
# 매일경제      1658  1658  1468  1658    1658    1510    1278        163
# 매일신문       124   124   124   124     124     100      84         24
# 머니투데이     1530  1530  1530  1530    1530    1383    1153        146
# 무등일보         9     9     9     9       9       8       8          2
# 문화일보       187   187   165   187     187     160     135         15
# 부산일보       166   166   158   166     166     140     119         21
# 서울경제      1407  1407  1407  1407    1407    1292    1084        125
# 서울신문       364   364   340   364     364     307     243         67
# 세계일보       523   523   455   523     523     461     382        117
# 아시아경제     1360  1360  1346  1360    1360    1250    1077        127
# 아주경제      1152  1152  1152  1152    1152    1052     875        122
# 영남일보        47    47    47    47      47      36      32          8
# 울산매일        16    16    16    16      16      16      13          6
# 전남일보        23    23    23    23      23      18      15          3
# 전북도민일보      20    20    20    20      20      16      12          9
# 전북일보        39    39    39    39      39      36      28         12
# 전자신문       289   289   225   289     289     251     208         23
# 제민일보         4     4     4     4       4       4       4          0
# 조선일보       696   696   634   696     696     645     545        110
# 중도일보        18    18    18    18      18      15      12          1
# 중부매일         6     6     6     6       6       4       4          3
# 중부일보        42    42    42    42      42      38      26          8
# 중앙일보       662   662   610   662     662     597     498        121
# 충북일보        13    13    13    13      13      11       9          1
# 충청일보        27    27    27    27      27      24      20          4
# 충청투데이       17    17    17    17      17      17      15          1
# 파이낸셜뉴스     390   390   390   390     390     370     324         31
# 한겨레        288   288   238   288     288     248     199         71
# 한국경제      2161  2161  2082  2161    2161    1980    1672        207
# 한국일보       335   335   288   335     335     277     235         76
# 한라일보        10    10    10    10      10       8       7          3
# 헤럴드경제     1241  1241  1241  1241    1241    1156     992        113
#
#         사건/사고 분류2  사건/사고 분류3    인물    위치    기관   키워드  특성추출(가중치순 상위 50개)    본문  \
# 언론사
# KBS             7          3   125   159   195   201                201   201
# MBC             4          2    74   107   121   124                124   124
# OBS             1          0    17    17    26    28                 28    28
# SBS             0          0    39    44    62    63                 63    63
# YTN            21         10   291   317   455   459                459   459
# 강원도민일보          1          0     7    13    14    14                 14    14
# 강원일보            0          0    17    29    32    33                 33    33
# 경기일보            0          0    19    20    22    22                 22    22
# 경남도민일보          1          0    12    19    23    24                 24    24
# 경남신문            0          0     2    14    13    14                 14    14
# 경상일보            1          0    13    22    29    29                 29    29
# 경인일보            2          0    26    49    44    58                 58    58
# 경향신문           14          6   157   179   232   233                233   233
# 광주매일신문          1          0    13    33    34    34                 34    34
# 광주일보            2          2    11    16    18    18                 18    18
# 국민일보           21          4   225   331  2206  2273               2273  2273
# 국제신문            0          0    39    55    61    62                 62    62
# 내일신문            2          0   114   146   188   189                189   189
# 대구일보            0          0    12    22    22    22                 22    22
# 대전일보            0          0    17    30    36    36                 36    36
# 동아일보            7          1   217   243   312   313                313   313
# 디지털타임스          7          1   356   441   603   606                606   606
# 매일경제           21          5  1103  1322  1651  1658               1658  1658
# 매일신문            4          2    92   103   122   124                124   124
# 머니투데이          24          4   980  1189  1529  1530               1530  1530
# 무등일보            0          0     7     9     9     9                  9     9
# 문화일보            1          0   114   140   187   187                187   187
# 부산일보            1          0    88   136   163   166                166   166
# 서울경제           17          5   826  1069  1401  1407               1407  1407
# 서울신문           13          3   284   308   363   364                364   364
# 세계일보           27          9   363   422   518   523                523   523
# 아시아경제          16          6   769  1042  1355  1360               1360  1360
# 아주경제           19          5   679   998  1146  1152               1152  1152
# 영남일보            0          0    28    43    45    47                 47    47
# 울산매일            3          0     9    14    15    16                 16    16
# 전남일보            1          0    13    19    23    23                 23    23
# 전북도민일보          0          0    17    17    20    20                 20    20
# 전북일보            1          0    27    34    39    39                 39    39
# 전자신문            4          1   174   212   288   289                289   289
# 제민일보            0          0     2     4     4     4                  4     4
# 조선일보           26         12   478   562   637   696                696   696
# 중도일보            0          0    12    15    17    18                 18    18
# 중부매일            1          0     5     6     6     6                  6     6
# 중부일보            2          1    30    37    42    42                 42    42
# 중앙일보           26          5   489   549   660   662                662   662
# 충북일보            0          0     5    11    12    13                 13    13
# 충청일보            1          0    15    25    26    27                 27    27
# 충청투데이           0          0     6    16    16    17                 17    17
# 파이낸셜뉴스          8          4   266   304   390   390                390   390
# 한겨레            22          5   202   234   285   288                288   288
# 한국경제           33          9  1330  1796  2153  2161               2161  2161
# 한국일보           17          6   238   293   329   335                335   335
# 한라일보            0          0     5     9    10    10                 10    10
# 헤럴드경제          11          1   719   965  1229  1241               1241  1241
#
#          URL  분석제외 여부
# 언론사
# KBS      201       43
# MBC      123        9
# OBS       28        0
# SBS       63        3
# YTN      459       45
# 강원도민일보    14        0
# 강원일보      33        0
# 경기일보      22        0
# 경남도민일보    24        0
# 경남신문       0        0
# 경상일보      29        0
# 경인일보      58       14
# 경향신문     233        9
# 광주매일신문    34        0
# 광주일보      18        0
# 국민일보    2273     1961
# 국제신문      62        0
# 내일신문     189        0
# 대구일보      22        0
# 대전일보      36        1
# 동아일보     313        4
# 디지털타임스   606      134
# 매일경제    1658       71
# 매일신문     124        3
# 머니투데이   1530       11
# 무등일보       9        0
# 문화일보     187        0
# 부산일보     166        3
# 서울경제    1407       97
# 서울신문     364       13
# 세계일보     523        8
# 아시아경제   1360       79
# 아주경제    1152        5
# 영남일보      47        0
# 울산매일      16        0
# 전남일보      22        0
# 전북도민일보    20        0
# 전북일보      39        0
# 전자신문     289        7
# 제민일보       0        0
# 조선일보     696       60
# 중도일보      18        1
# 중부매일       6        0
# 중부일보      42        4
# 중앙일보     662        0
# 충북일보      13        0
# 충청일보      27        1
# 충청투데이     17        0
# 파이낸셜뉴스   390        1
# 한겨레      288        1
# 한국경제    2161       84
# 한국일보     335        1
# 한라일보      10        0
# 헤럴드경제   1241      220

# %%
import warnings
warnings.filterwarnings(action='ignore') 

import numpy as np

# %%
news_df = pd.read_csv('news.csv')
news_df.sort_values(by=['일자'], axis=0, inplace=True)
news_data = news_df[['일자', '언론사']]

df_YTN = news_data[news_data['언론사'] == 'YTN']
df_KukMin = news_data[news_data['언론사'] == '국민일보']
df_GyeongJe = news_data[news_data['언론사'] == '매일경제']
df_Money = news_data[news_data['언론사'] == '머니투데이']
df_Seoul = news_data[news_data['언론사'] == '서울경제']
df_Asia = news_data[news_data['언론사'] == '아시아경제']
df_Aju = news_data[news_data['언론사'] == '아주경제']

# %%
df_YTN['date'] = pd.to_datetime(df_YTN['일자'].astype(str), format='%Y%m%d')
df_YTN.set_index(df_YTN['date'], inplace=True)
df_YTN['YTN'] = 1
df_YTN = df_YTN.drop('일자', 1)
df_YTN = df_YTN.drop('언론사', 1)
df_YTN = df_YTN.drop('date', 1)

# %%
df_KukMin['date'] = pd.to_datetime(df_KukMin['일자'].astype(str), format='%Y%m%d')
df_KukMin.set_index(df_KukMin['date'], inplace=True)
df_KukMin['국민일보'] = 1
df_KukMin = df_KukMin.drop('일자', 1)
df_KukMin = df_KukMin.drop('언론사', 1)
df_KukMin = df_KukMin.drop('date', 1)

# %%
df_GyeongJe['date'] = pd.to_datetime(df_GyeongJe['일자'].astype(str), format='%Y%m%d')
df_GyeongJe.set_index(df_GyeongJe['date'], inplace=True)
df_GyeongJe['매일경제'] = 1
df_GyeongJe = df_GyeongJe.drop('일자', 1)
df_GyeongJe = df_GyeongJe.drop('언론사', 1)
df_GyeongJe = df_GyeongJe.drop('date', 1)

# %%
df_Money['date'] = pd.to_datetime(df_Money['일자'].astype(str), format='%Y%m%d')
df_Money.set_index(df_Money['date'], inplace=True)
df_Money['머니투데이'] = 1
df_Money = df_Money.drop('일자', 1)
df_Money = df_Money.drop('언론사', 1)
df_Money = df_Money.drop('date', 1)

# %%
df_Seoul['date'] = pd.to_datetime(df_Seoul['일자'].astype(str), format='%Y%m%d')
df_Seoul.set_index(df_Seoul['date'], inplace=True)
df_Seoul['서울경제'] = 1
df_Seoul = df_Seoul.drop('일자', 1)
df_Seoul = df_Seoul.drop('언론사', 1)
df_Seoul = df_Seoul.drop('date', 1)

# %%
df_Asia['date'] = pd.to_datetime(df_Asia['일자'].astype(str), format='%Y%m%d')
df_Asia.set_index(df_Asia['date'], inplace=True)
df_Asia['아시아경제'] = 1
df_Asia = df_Asia.drop('일자', 1)
df_Asia = df_Asia.drop('언론사', 1)
df_Asia = df_Asia.drop('date', 1)

# %%
df_Aju['date'] = pd.to_datetime(df_Aju['일자'].astype(str), format='%Y%m%d')
df_Aju.set_index(df_Aju['date'], inplace=True)
df_Aju['아주경제'] = 1
df_Aju = df_Aju.drop('일자', 1)
df_Aju = df_Aju.drop('언론사', 1)
df_Aju = df_Aju.drop('date', 1)

# %%
total_sum = pd.concat([df_YTN.resample(rule='QS').sum(), df_KukMin.resample(rule='QS').sum(),
                     df_GyeongJe.resample(rule='QS').sum(), df_Money.resample(rule='QS').sum(),
                      df_Seoul.resample(rule='QS').sum(), df_Aju.resample(rule='QS').sum(),
                      df_Asia.resample(rule='QS').sum()])

# %%
total_sum.to_csv('Nearby three-months news.csv', index=True, mode='w', encoding='utf-8')

# %%
total_sum
# Out:
#               YTN    국민일보    매일경제   머니투데이    서울경제   아주경제   아시아경제
# date
# 2021-04-01  371.0     NaN     NaN     NaN     NaN    NaN     NaN
# 2021-07-01   88.0     NaN     NaN     NaN     NaN    NaN     NaN
# 2021-04-01    NaN  1591.0     NaN     NaN     NaN    NaN     NaN
# 2021-07-01    NaN   682.0     NaN     NaN     NaN    NaN     NaN
# 2021-04-01    NaN     NaN  1283.0     NaN     NaN    NaN     NaN
# 2021-07-01    NaN     NaN   375.0     NaN     NaN    NaN     NaN
# 2021-04-01    NaN     NaN     NaN  1172.0     NaN    NaN     NaN
# 2021-07-01    NaN     NaN     NaN   358.0     NaN    NaN     NaN
# 2021-04-01    NaN     NaN     NaN     NaN  1052.0    NaN     NaN
# 2021-07-01    NaN     NaN     NaN     NaN   355.0    NaN     NaN
# 2021-04-01    NaN     NaN     NaN     NaN     NaN  861.0     NaN
# 2021-07-01    NaN     NaN     NaN     NaN     NaN  291.0     NaN
# 2021-04-01    NaN     NaN     NaN     NaN     NaN    NaN  1001.0
# 2021-07-01    NaN     NaN     NaN     NaN     NaN    NaN   359.0

# %%
news_feature = news_df['특성추출(가중치순 상위 50개)'].values.tolist()
keyword = []
for i in news_feature:
    for y in i.split(','):
        keyword.append(y)

# %%
from collections import Counter

# %%
count = Counter(keyword)
tags = count.most_common(50)
print(dict(tags))
# Out:
# {'투자자': 4394, '미국': 4319, '주식': 3379, '관계자': 3202, '코로나19': 2377, '거래일': 2343, '공시': 2284, '보고서': 2272, '거래량': 2063, '대비': 2055, '지분': 1974, '지분율': 1926, '한국': 1894, '전문': 1860, '보유': 1850, '직전': 1849, '이동': 1830, '추가': 1791, '매각': 1770, '개인': 1755, '거래소': 1749, '법인': 1735, '변동': 1730, '관계인': 1727, '특수관계인': 1715, '매입': 1710, '포함': 1703, '특수': 1700, '특별관계자': 1691, '특별': 1689, '상황': 1685, '지분변동': 1682, '주식등': 1682, '일명': 1682, '대량보유상황보고서': 1681, '대량': 1648, '상장': 1642, '코스피': 1631, '부동산': 1618, '회사': 1453, '중국': 1393, '기업': 1330, '코스닥': 1307, '외국인': 1223, '삼성전자': 1222, '가능성': 1209, '투자자들': 1204, '종가': 1194, '증권사': 1159, '마감': 1157}

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
wc = WordCloud(font_path='c:/windows/fonts/malgun.ttf',background_color='white', width=1000, height=800)
cloud = wc.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)

# %%
news_data = news_df['키워드'].values.tolist()
keyword = []
nouns = ''
for i in news_data:
    for y in i.split(','):
        nouns +=y+' '
    keyword.append(nouns)
    nouns=''

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfv = TfidfVectorizer(ngram_range=(1,1))
vec_text = tfv.fit_transform(keyword)
words = tfv.get_feature_names()

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters = 10, n_init = 17, n_jobs = -1, tol = 0.01, max_iter = 2000)
kmeans.fit(vec_text)
common_words = kmeans.cluster_centers_.argsort()[:, -1:-5:-1]
print(common_words)
for num, centroid in enumerate(common_words):
    print(str(num) + ' : ' + ' , '.join(words[word] for word in centroid))
# Out:
# [[130839  31882  94554  75867]
#  [ 35182  35180 101189 107027]
#  [ 35396 110528  12630  63141]
#  [132058  28978 118235  83206]
#  [107819  41352 121289 107339]
#  [121289  20137 123791  33659]
#  [ 70167  89618  58094 110681]
#  [113936  25404  35205  35253]
#  [ 70113  65422  69625  70092]
#  [ 39839  48514  28730  97210]]
# 0 : 혐의 , 검찰 , 의원 , 수사
# 1 : 공매도 , 공매 , 재개 , 종목
# 2 : 공시 , 지분 , 5일 , 변동
# 3 : 화폐 , 가상 , 코인 , 암호
# 4 : 주식 , 기업 , 투자 , 주가
# 5 : 투자 , etf , 펀드 , 고객
# 6 : 상승 , 외국인 , 미국 , 지수
# 7 : 청약 , skiet , 공모 , 공모주
# 8 : 상속세 , 부회장 , 삼성생명 , 상속
# 9 : 금리 , 대출 , 가계 , 인상
